# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import seaborn as sns
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import precision_score

# %%
target = []
images = []
flat_data = []
PATH = 'C:\\Users\\YakupAkdin\\AAAaVeriMadenciligi\\data'
#''
cate = ['arp','baglama','elektroGitar','gitar','kanun','keman','kemence','mandolin','ud','yayliTambur']
import io            
#Görüntü Formatı ve diziye atama
for category in cate:
    class_num = cate.index(category)
    path = os.path.join(PATH,category)
    for img in os.listdir(path):
        print(img)
        img_array = imread(os.path.join(path,img))
        img_array= resize(img_array, (64,64,3))
        images.append(img_array)
        img_array = img_array.flatten()
        flat_data.append(img_array)
        target.append(class_num)
           
flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)
# Out:
# arp(1).jpg
# arp(10).jpg
# arp(100).jpg
# arp(101).jpg
# arp(103).jpg
# arp(104).jpg
# arp(105).jpg
# arp(106).jpg
# arp(107).jpg
# arp(108).jpg
# arp(109).jpg
# arp(11).jpg
# arp(110).jpg
# arp(111).jpg
# arp(112).jpg
# arp(113).jpg
# arp(114).jpg
# arp(115).jpg
# arp(116).jpg
# arp(117).jpg
# arp(118).jpg
# arp(119).jpg
# arp(12).jpg
# arp(120).jpg
# arp(121).jpg
# arp(122).jpg
# arp(123).jpg
# arp(124).jpg
# arp(125).jpg
# arp(126).jpg
# arp(127).jpg
# arp(128).jpg
# arp(129).jpg
# arp(13).jpg
# arp(130).jpg
# arp(131).jpg
# arp(132).jpg
# arp(133).jpg
# arp(134).jpg
# arp(135).jpg
# arp(136).jpg
# arp(137).jpg
# arp(138).jpg
# arp(139).jpg
# arp(14).jpg
# arp(140).jpg
# arp(141).jpg
# arp(142).jpg
# arp(143).jpg
# arp(144).jpg
# arp(145).jpg
# arp(146).jpg
# arp(147).jpg
# arp(148).jpg
# arp(149).jpg
# arp(15).jpg
# arp(150).jpg
# arp(151).jpg
# arp(152).jpg
# arp(153).jpg
# arp(154).jpg
# arp(155).jpg
# arp(156).jpg
# arp(157).jpg
# arp(158).jpg
# arp(159).jpg
# arp(16).jpg
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
#Train-Test
x_train, x_test, y_train, y_test = train_test_split(flat_data,target,test_size=0.3)

model=RandomForestClassifier()

# %%
#Eğitme
model.fit(x_train,y_train)


y_pred=model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics

#Grafik
p = classification_report(y_pred,y_test, target_names=cate)
accuracy_score(y_pred,y_test)
print(classification_report(y_pred,y_test))
print ("Precision = %.3f" % precision_score(y_test, y_pred,average = 'weighted'))
#sensitivity
sensitivity1 = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity : ', sensitivity1 )
#specificity
specificity1 = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : ', specificity1)
print("Precision = %.3f" % metrics.precision_score(y_test, y_pred, average='weighted'))
acc = metrics.accuracy_score(y_test, y_pred)
error_rate = 1-acc
#accuracy
print("Accuracy:",acc)
#error rate
print("Error-rate = ",error_rate)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.89      0.25         9
#            1       0.78      0.52      0.62       535
#            2       0.75      0.65      0.70       588
#            3       0.76      0.81      0.78       580
#            4       0.46      0.37      0.41       165
#            5       0.57      0.68      0.62       187
#            6       0.31      0.64      0.42        69
#            7       0.18      0.37      0.24        78
#            8       0.56      0.51      0.53       251
#            9       0.10      0.80      0.18         5
#
#     accuracy                           0.62      2467
#    macro avg       0.46      0.62      0.48      2467
# weighted avg       0.67      0.62      0.64      2467
#
# Precision = 0.634
# Sensitivity :  0.5
# Specificity :  1.0
# Precision = 0.634
# Accuracy: 0.6205918119173085
# Error-rate =  0.3794081880826915

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(cm, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)),cbar=True,ax=ax)
# Out:
# <AxesSubplot: >
